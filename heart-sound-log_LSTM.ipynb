# %%
import os
import glob
import numpy as np
from tqdm import tqdm
import itertools
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Audio
import librosa
import librosa.display

# Scikit learn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix as sk_plot_confusion_matrix
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU, MaxPooling1D

# Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
# Keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Flatten, BatchNormalization, Reshape
from keras.layers.convolutional import Conv2D, MaxPooling2D, Conv1D
from tensorflow.keras.utils import to_categorical

# TensorFlow
from tensorflow.keras.utils import to_categorical

# Ignore warnings
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

dataset = []
for folder in ["Heartbeat_Sounds/set_a/**","Heartbeat_Sounds/set_b/**"]:
    for filename in glob.iglob(folder):
        if os.path.exists(filename):
            label = os.path.basename(filename).split("_")[0]
            duration = librosa.get_duration(filename=filename)
            # skip audio smaller than 3 secs
            if duration>=3:
                slice_size = 3
                iterations = int((duration-slice_size)/(slice_size-1))
                iterations += 1
#                 initial_offset = (duration % slice_size)/2
                initial_offset = (duration - ((iterations*(slice_size-1))+1))/2
                if label not in ["Aunlabelledtest", "Bunlabelledtest"]:
                    for i in range(iterations):
                        offset = initial_offset + i*(slice_size-1)
                        
                        dataset.append({
                                "filename": filename,
                                "label": label,
                                "offset": offset
                            })
                       
                        
dataset = pd.DataFrame(dataset)
dataset = shuffle(dataset, random_state=42)
dataset.info()

# Function to extract features
def extract_features(audio_path, offset):
    y, sr = librosa.load(audio_path, offset=offset, duration=3)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    return mfccs

# Extract features for all data points
x_data = []
for idx in tqdm(range(len(dataset))):
    x_data.append(extract_features(dataset.filename.iloc[idx], dataset.offset.iloc[idx]))

# Convert to numpy array
x_data = np.asarray(x_data)

# Encode Labels
encoder = LabelEncoder()
encoder.fit(dataset.label)
y_data = encoder.transform(dataset.label)

unique_labels = dataset['label'].unique()
num_classes = len(unique_labels)

# Compute class weights
class_weights = class_weight.compute_class_weight(class_weight="balanced", classes=np.unique(y_data), y=y_data)

y_data_one_hot = to_categorical(y_data, num_classes=num_classes)


# Initialize StratifiedKFold with train_size and test_size
kfold = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)

# Initialize lists to store results for each fold
train_accuracies = []
test_accuracies = []
train_auc_scores = []
test_auc_scores = []
train_mcc_scores = []
test_mcc_scores = []
train_conf_matrices = []
test_conf_matrices = []
train_class_reports = []
test_class_reports = []
cm_test_normalized = []
report_test_list = []
cm_test_normalized_list = []

# Open the common results file in 'w' mode to overwrite existing content
with open('results_heartSound/all_folds_lstm5_results.txt', 'w') as common_file:
    # Split the indices instead of the dataset
    for fold, (train_index, test_index) in enumerate(kfold.split(x_data, y_data_one_hot), 1):
        x_train_fold, x_test_fold = x_data[train_index], x_data[test_index]
        y_train_fold, y_test_fold = y_data_one_hot[train_index], y_data_one_hot[test_index]

        model = Sequential()

        model.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(40, 130)))
        model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
        model.add(BatchNormalization())

        model.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(40, 130)))
        model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
        lstm_model.add(BatchNormalization())

        model.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
        model.add(MaxPooling1D(pool_size=2, strides = 2, padding = 'same'))
        model.add(BatchNormalization())

        model.add(LSTM(256, return_sequences=True))
        model.add(LSTM(128))


        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.5))

        model.add(Dense(32, activation='relu'))
        model.add(Dropout(0.5))

        model.add(Dense(num_classes, activation='softmax'))


        model.summary()

        # Compile the model
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        your_epochs = 300  # You can choose an appropriate number of epochs
        your_batch_size = 128  # You can choose an appropriate batch size

        # Train and evaluate the model for the current fold
        model.fit(x_train_fold, y_train_fold, epochs=your_epochs, batch_size=your_batch_size)
        y_pred_train = model.predict(x_train_fold)
        y_pred_test = model.predict(x_test_fold)
        
        y_pred_test_labels = np.argmax(y_pred_test, axis=1)
        report_test = classification_report(np.argmax(y_test_fold, axis=1), y_pred_test_labels, output_dict=True)

        # Calculate metrics for train set
        train_accuracy = accuracy_score(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1))
        train_auc = roc_auc_score(y_train_fold, y_pred_train, multi_class='ovr')
        train_mcc = matthews_corrcoef(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1))
        train_cm = confusion_matrix(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1))
        train_class_report = classification_report(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1), target_names=encoder.classes_)

        # Calculate metrics for test set
        test_accuracy = accuracy_score(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))
        test_auc = roc_auc_score(y_test_fold, y_pred_test, multi_class='ovr')
        test_mcc = matthews_corrcoef(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))
        test_cm = confusion_matrix(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))
        test_class_report = classification_report(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1), target_names=encoder.classes_)

        # Inside the loop where you append accuracies to lists
        train_accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)

        # Calculate std for train and test accuracies
        train_accuracy_std = np.std(train_accuracies)
        test_accuracy_std = np.std(test_accuracies)


        # Save results to the common text file for both train and test sets
        common_file.write(f'Fold {fold} Results:\n')
        common_file.write(f'Train Accuracy: {train_accuracy} (std: {train_accuracy_std})\n')
        common_file.write(f'Train AUC Score: {train_auc}\n')
        common_file.write(f'Train MCC Score: {train_mcc}\n\n')
        common_file.write('Train Confusion Matrix:\n')
        common_file.write(str(train_cm))
        common_file.write('\n\nTrain Classification Report:\n')
        common_file.write(train_class_report)

        common_file.write(f'\n\nTest Accuracy: {test_accuracy} (std: {test_accuracy_std})\n')
        common_file.write(f'Test AUC Score: {test_auc}\n')
        common_file.write(f'Test MCC Score: {test_mcc}\n\n')
        common_file.write('Test Confusion Matrix:\n')
        common_file.write(str(test_cm))
        common_file.write('\n\nTest Classification Report:\n')
        common_file.write(test_class_report)
        
        # Print a separator between folds
        common_file.write("\n" + "="*40 + "\n")
        
        # Calculate average metrics for train set
        avg_train_accuracy = np.mean(train_accuracies)
        avg_train_auc = np.mean(train_auc_scores)
        avg_train_mcc = np.mean(train_mcc_scores)
        avg_train_conf_matrix = np.mean(train_conf_matrices, axis=0)  # Average confusion matrix

        # Convert continuous probabilities to class labels using argmax
        y_pred_train_class = np.argmax(y_pred_train, axis=1)

        # Calculate average metrics for test set
        avg_test_accuracy = np.mean(test_accuracies)
        avg_test_auc = np.mean(test_auc_scores)
        avg_test_mcc = np.mean(test_mcc_scores)
        avg_test_conf_matrix = np.mean(test_conf_matrices, axis=0)  # Average confusion matrix

        # Convert continuous probabilities to class labels using argmax
        y_pred_test_class = np.argmax(y_pred_test, axis=1)
        
        # Calculate average results for train set
        avg_train_class_report = classification_report(np.argmax(y_train_fold, axis=1), y_pred_train_class, target_names=encoder.classes_)

        # Calculate average results for test set
        avg_test_class_report = classification_report(np.argmax(y_test_fold, axis=1), y_pred_test_class, target_names=encoder.classes_)


        # Inside the loop where you plot confusion matrices
        plt.figure()
        train_cm = confusion_matrix(np.argmax(y_train_fold, axis=1), y_pred_train.argmax(axis=1))

        # Round each value in the confusion matrix to 5 decimal places
        rounded_train_cm = np.round(train_cm / np.sum(train_cm, axis=1)[:, np.newaxis], 5)

        sns.heatmap(rounded_train_cm, annot=True, fmt='.5f', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
        plt.title(f'Train Confusion Matrix - Fold {fold}')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.savefig(f'LSTM/train_confusion_matrix_fold_{fold}.png')
        plt.close()

        # Inside the loop where you plot confusion matrices
        plt.figure()
        test_cm = confusion_matrix(np.argmax(y_test_fold, axis=1), y_pred_test.argmax(axis=1))

        # Round each value in the confusion matrix to 5 decimal places
        rounded_test_cm = np.round(test_cm / np.sum(test_cm, axis=1)[:, np.newaxis], 5)

        sns.heatmap(rounded_test_cm, annot=True, fmt='.5f', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
        plt.title(f'Test Confusion Matrix - Fold {fold}')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.savefig(f'LSTM/test_confusion_matrix_fold_{fold}.png')
        plt.close()

        # Inside the loop where you append results to lists
        train_accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)
        train_auc_scores.append(train_auc)
        test_auc_scores.append(test_auc)
        train_mcc_scores.append(train_mcc)
        test_mcc_scores.append(test_mcc)
        train_conf_matrices.append(train_cm)
        test_conf_matrices.append(test_cm)
        train_class_reports.append(train_class_report)
        test_class_reports.append(test_class_report)
        
        # Print a separator between folds
        common_file.write("\n" + "="*40 + "\n")
        
        # Append classification report and confusion matrix to lists
        report_test_list.append(report_test)
        cm_test_normalized_list.append(cm_test_normalized)
        

    # Calculate average metrics for train set
    avg_train_accuracy = np.mean(train_accuracies)
    avg_train_auc = np.mean(train_auc_scores)
    avg_train_mcc = np.mean(train_mcc_scores)

    # Reshape y_train_fold to (num_samples, num_classes)
    y_train_fold_reshaped = to_categorical(y_train_fold, num_classes=len(encoder.classes_))

    # Convert predictions to one-hot encoding
    y_pred_train_one_hot = to_categorical(np.argmax(y_pred_train, axis=1), num_classes=len(encoder.classes_))

    # Calculate average confusion matrix for train set
    avg_train_conf_matrix = np.mean(train_conf_matrices, axis=0).astype(int)


    # Calculate average classification report for train set
    avg_train_class_report = classification_report(
        np.argmax(y_train_fold, axis=1), 
        np.argmax(y_pred_train_one_hot, axis=1), 
        target_names=encoder.classes_, 
        digits=5
    )
    

    # Calculate average metrics for test set
    avg_test_accuracy = np.mean(test_accuracies)
    avg_test_auc = np.mean(test_auc_scores)
    avg_test_mcc = np.mean(test_mcc_scores)

    # Reshape y_test_fold to (num_samples, num_classes)
    y_test_fold_reshaped = to_categorical(y_test_fold, num_classes=len(encoder.classes_))

    # Convert predictions to one-hot encoding
    y_pred_test_one_hot = to_categorical(np.argmax(y_pred_test, axis=1), num_classes=len(encoder.classes_))

    # Calculate average confusion matrix for test set
    avg_test_conf_matrix = np.mean(test_conf_matrices, axis=0).astype(int)

    # Calculate average classification report for test set
    avg_test_class_report = classification_report(
        np.argmax(y_test_fold, axis=1), 
        np.argmax(y_pred_test_one_hot, axis=1), 
        target_names=encoder.classes_, 
        digits=5
    )

    # Inside the loop where you plot the average confusion matrix for the test set
    avg_cm_test_normalized = np.mean(cm_test_normalized_list, axis=0)
    plt.figure()

    avg_test_cm = confusion_matrix(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))

    # Normalize the confusion matrix by dividing each value by the sum of its row
    normalized_avg_test_cm = avg_test_cm / avg_test_cm.sum(axis=1)[:, np.newaxis]

    # Plot confusion matrix for the average test set
    plt.figure()
    sns.heatmap(normalized_avg_test_cm, annot=True, fmt='.5f', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
    plt.title(f'Average Test Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.savefig('LSTM/average_test_confusion_matrix.png')
    plt.close()



    # Save average results to the common text file
    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Test Accuracy: {avg_test_accuracy:.5f} (std: {np.std(test_accuracies):.5f})\n')
    common_file.write(f'Average Test AUC Score: {avg_test_auc:.5f}\n')
    common_file.write(f'Average Test MCC Score: {avg_test_mcc:.5f}\n\n')
    common_file.write('Average Test Confusion Matrix:\n')
    common_file.write(str(avg_cm_test_normalized.round(5).astype(int)))  # Display confusion matrix with 5 decimal places
    common_file.write("\n\nAverage Test Classification Report:\n")
    common_file.write(str(avg_test_class_report))


    # Print and write the average results to the common text file
    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Test Accuracy: {avg_test_accuracy:.5f} (std: {np.std(test_accuracies):.5f})\n')
    common_file.write(f'Average Test AUC Score: {avg_test_auc:.5f}\n')
    common_file.write(f'Average Test MCC Score: {avg_test_mcc:.5f}\n\n')
    common_file.write('Average Test Confusion Matrix:\n')
    common_file.write(str(avg_cm_test_normalized.round(5).astype(int)))  # Display confusion matrix with 5 decimal places
    common_file.write("\n\nAverage Test Classification Report:\n")
    common_file.write(str(avg_test_class_report))


    # Print and write the average results to the common text file
    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Train Accuracy: {avg_train_accuracy} (std: {np.std(train_accuracies)})\n')
    common_file.write(f'Average Train AUC Score: {avg_train_auc}\n')
    common_file.write(f'Average Train MCC Score: {avg_train_mcc}\n\n')
    common_file.write('Average Train Confusion Matrix:\n')
    common_file.write(str(avg_train_conf_matrix.astype(int)))
    common_file.write("\n\nAverage Train Classification Report:\n")
    common_file.write(str(avg_train_class_report))

    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Test Accuracy: {avg_test_accuracy} (std: {np.std(test_accuracies)})\n')
    common_file.write(f'Average Test AUC Score: {avg_test_auc}\n')
    common_file.write(f'Average Test MCC Score: {avg_test_mcc}\n\n')
    common_file.write('Average Test Confusion Matrix:\n')
    common_file.write(str(avg_test_conf_matrix.astype(int)))
    common_file.write("\n\nAverage Test Classification Report:\n")
    common_file.write(str(avg_test_class_report))
        
    # Print average results for train set
    print(f'Average Train Accuracy: {avg_train_accuracy}')
    print(f'Average Train AUC Score: {avg_train_auc}')
    print(f'Average Train MCC Score: {avg_train_mcc} \n')
    print("\nAverage Train Classification Report:")
    print(avg_train_class_report)

    # Print average results for test set
    print(f'Average Test Accuracy: {avg_test_accuracy}')
    print(f'Average Test AUC Score: {avg_test_auc}')
    print(f'Average Test MCC Score: {avg_test_mcc} \n')
    print("\nAverage Test Classification Report:")
    print(avg_test_class_report)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1441 entries, 168 to 1126
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  1441 non-null   object
#  1   label     1441 non-null   object
#  2   offset    1441 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 45.0+ KB
# 100%|███████████████████████████████████████████████████████████████████████████████| 1441/1441 [03:19<00:00,  7.22it/s]
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_11 (Conv1D)          (None, 40, 2048)          1333248
#
#  max_pooling1d_9 (MaxPooling  (None, 20, 2048)         0
#  1D)
#
#  batch_normalization_9 (Batc  (None, 20, 2048)         8192
#  hNormalization)
#
#  conv1d_12 (Conv1D)          (None, 20, 1024)          10486784
#
#  max_pooling1d_10 (MaxPoolin  (None, 10, 1024)         0
#  g1D)
#
#  conv1d_13 (Conv1D)          (None, 10, 512)           2621952
#
#  max_pooling1d_11 (MaxPoolin  (None, 5, 512)           0
#  g1D)
#
#  batch_normalization_11 (Bat  (None, 5, 512)           2048
#  chNormalization)
#
#  lstm_6 (LSTM)               (None, 5, 256)            787456
#
#  lstm_7 (LSTM)               (None, 128)               197120
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  dropout_6 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  dropout_7 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 15,447,301
# Trainable params: 15,442,181
# Non-trainable params: 5,120
# _________________________________________________________________
# Epoch 1/300
# 9/9 [==============================] - 218s 19s/step - loss: 1.3967 - accuracy: 0.4132
# Epoch 2/300
# 9/9 [==============================] - 139s 15s/step - loss: 1.2035 - accuracy: 0.5373
# Epoch 3/300
# 9/9 [==============================] - 175s 19s/step - loss: 1.1080 - accuracy: 0.5651
# Epoch 4/300
# 9/9 [==============================] - 175s 19s/step - loss: 1.0607 - accuracy: 0.5816
# Epoch 5/300
# 9/9 [==============================] - 214s 24s/step - loss: 1.0218 - accuracy: 0.5885
# Epoch 6/300
# 9/9 [==============================] - 249s 28s/step - loss: 0.9963 - accuracy: 0.6163
# Epoch 7/300
# 9/9 [==============================] - 223s 25s/step - loss: 0.9397 - accuracy: 0.6372
# Epoch 8/300
# 9/9 [==============================] - 211s 24s/step - loss: 0.9132 - accuracy: 0.6615
# Epoch 9/300
# 9/9 [==============================] - 204s 22s/step - loss: 0.9032 - accuracy: 0.6536
# Epoch 10/300
# 9/9 [==============================] - 224s 25s/step - loss: 0.8723 - accuracy: 0.6797
# Epoch 11/300
# 9/9 [==============================] - 213s 24s/step - loss: 0.8430 - accuracy: 0.7005
# Epoch 12/300
# 9/9 [==============================] - 216s 23s/step - loss: 0.8353 - accuracy: 0.7057
# Epoch 13/300
# 9/9 [==============================] - 184s 21s/step - loss: 0.8114 - accuracy: 0.7240
# Epoch 14/300
# 9/9 [==============================] - 220s 24s/step - loss: 0.8141 - accuracy: 0.7040
# Epoch 15/300
# 9/9 [==============================] - 222s 25s/step - loss: 0.7592 - accuracy: 0.7300
# Epoch 16/300
# 9/9 [==============================] - 218s 24s/step - loss: 0.7546 - accuracy: 0.7361
# Epoch 17/300
# 9/9 [==============================] - 217s 24s/step - loss: 0.7429 - accuracy: 0.7483
# Epoch 18/300
# 9/9 [==============================] - 217s 24s/step - loss: 0.7186 - accuracy: 0.7500
# Epoch 19/300
# 9/9 [==============================] - 215s 24s/step - loss: 0.7469 - accuracy: 0.7344
# Epoch 20/300
# 9/9 [==============================] - 211s 24s/step - loss: 0.7328 - accuracy: 0.7491
# Epoch 21/300
# 9/9 [==============================] - 217s 24s/step - loss: 0.7831 - accuracy: 0.7396
# Epoch 22/300
# 9/9 [==============================] - 215s 24s/step - loss: 0.6894 - accuracy: 0.7726
# Epoch 23/300
# 9/9 [==============================] - 217s 24s/step - loss: 0.6857 - accuracy: 0.7656
# Epoch 24/300
# 9/9 [==============================] - 219s 24s/step - loss: 0.6702 - accuracy: 0.7778
# Epoch 25/300
# 9/9 [==============================] - 217s 24s/step - loss: 0.6650 - accuracy: 0.7639
# Epoch 26/300
# 9/9 [==============================] - 215s 24s/step - loss: 0.6740 - accuracy: 0.7656
# Epoch 27/300
# 9/9 [==============================] - 215s 24s/step - loss: 0.6224 - accuracy: 0.7847
# Epoch 28/300
# 9/9 [==============================] - 198s 22s/step - loss: 0.6192 - accuracy: 0.7960
# Epoch 29/300
# 9/9 [==============================] - 209s 24s/step - loss: 0.6056 - accuracy: 0.7908
# Epoch 30/300
# 9/9 [==============================] - 212s 24s/step - loss: 0.6498 - accuracy: 0.7717
# Epoch 31/300
# 9/9 [==============================] - 215s 24s/step - loss: 0.5592 - accuracy: 0.8038
# Epoch 32/300
# 9/9 [==============================] - 218s 24s/step - loss: 0.5069 - accuracy: 0.8116
# Epoch 33/300
# 9/9 [==============================] - 214s 24s/step - loss: 0.5090 - accuracy: 0.8090
# Epoch 34/300
# 9/9 [==============================] - 215s 24s/step - loss: 0.4559 - accuracy: 0.8325
# Epoch 35/300
# 9/9 [==============================] - 180s 20s/step - loss: 0.4706 - accuracy: 0.8273
# Epoch 36/300
# 9/9 [==============================] - 168s 19s/step - loss: 0.4689 - accuracy: 0.8255
# Epoch 37/300
# 9/9 [==============================] - 163s 18s/step - loss: 0.4855 - accuracy: 0.8255
# Epoch 38/300
# 9/9 [==============================] - 169s 19s/step - loss: 0.4481 - accuracy: 0.8524
# Epoch 39/300
# 9/9 [==============================] - 168s 19s/step - loss: 0.5635 - accuracy: 0.8073
# Epoch 40/300
# 9/9 [==============================] - 169s 19s/step - loss: 0.4952 - accuracy: 0.8247
# Epoch 41/300
# 9/9 [==============================] - 171s 19s/step - loss: 0.4080 - accuracy: 0.8455
# Epoch 42/300
# 9/9 [==============================] - 165s 18s/step - loss: 0.3826 - accuracy: 0.8516
# Epoch 43/300
# 9/9 [==============================] - 171s 19s/step - loss: 0.3934 - accuracy: 0.8472
# Epoch 44/300
# 9/9 [==============================] - 170s 19s/step - loss: 0.3234 - accuracy: 0.8759
# Epoch 45/300
# 9/9 [==============================] - 166s 18s/step - loss: 0.3547 - accuracy: 0.8628
# Epoch 46/300
# 9/9 [==============================] - 151s 16s/step - loss: 0.3269 - accuracy: 0.8845
# Epoch 47/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.2992 - accuracy: 0.8793
# Epoch 48/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.3387 - accuracy: 0.8741
# Epoch 49/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.4438 - accuracy: 0.8464
# Epoch 50/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.3945 - accuracy: 0.8655
# Epoch 51/300
# 9/9 [==============================] - 120s 13s/step - loss: 0.4772 - accuracy: 0.8325
# Epoch 52/300
# 9/9 [==============================] - 121s 14s/step - loss: 0.5061 - accuracy: 0.8073
# Epoch 53/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.3764 - accuracy: 0.8663
# Epoch 54/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.3480 - accuracy: 0.8611
# Epoch 55/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.4143 - accuracy: 0.8516
# Epoch 56/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.3528 - accuracy: 0.8611
# Epoch 57/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.2912 - accuracy: 0.8854
# Epoch 58/300
# 9/9 [==============================] - 120s 13s/step - loss: 0.2886 - accuracy: 0.8863
# Epoch 59/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.3223 - accuracy: 0.8793
# Epoch 60/300
# 9/9 [==============================] - 123s 13s/step - loss: 0.3256 - accuracy: 0.8759
# Epoch 61/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.3335 - accuracy: 0.8733
# Epoch 62/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.3173 - accuracy: 0.8750
# Epoch 63/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.3004 - accuracy: 0.8802
# Epoch 64/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.2988 - accuracy: 0.8828
# Epoch 65/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.2961 - accuracy: 0.8872
# Epoch 66/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.2858 - accuracy: 0.8819
# Epoch 67/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.3368 - accuracy: 0.8767
# Epoch 68/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.2387 - accuracy: 0.9062
# Epoch 69/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.1967 - accuracy: 0.9028
# Epoch 70/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.2190 - accuracy: 0.9036
# Epoch 71/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2476 - accuracy: 0.9097
# Epoch 72/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2427 - accuracy: 0.9036
# Epoch 73/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2972 - accuracy: 0.8854
# Epoch 74/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2493 - accuracy: 0.8880
# Epoch 75/300
# 9/9 [==============================] - 121s 14s/step - loss: 0.1918 - accuracy: 0.9280
# Epoch 76/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1991 - accuracy: 0.9297
# Epoch 77/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.1949 - accuracy: 0.9201
# Epoch 78/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.4320 - accuracy: 0.8620
# Epoch 79/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.5048 - accuracy: 0.8220
# Epoch 80/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.3478 - accuracy: 0.8759
# Epoch 81/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.2629 - accuracy: 0.8932
# Epoch 82/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.2433 - accuracy: 0.8915
# Epoch 83/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.1934 - accuracy: 0.9141
# Epoch 84/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1778 - accuracy: 0.9280
# Epoch 85/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2203 - accuracy: 0.9210
# Epoch 86/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.2146 - accuracy: 0.9141
# Epoch 87/300
# 9/9 [==============================] - 119s 13s/step - loss: 0.2498 - accuracy: 0.9219
# Epoch 88/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2066 - accuracy: 0.9271
# Epoch 89/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2123 - accuracy: 0.9167
# Epoch 90/300
# 9/9 [==============================] - 120s 13s/step - loss: 0.2290 - accuracy: 0.9106
# Epoch 91/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1736 - accuracy: 0.9314
# Epoch 92/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1834 - accuracy: 0.9236
# Epoch 93/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1508 - accuracy: 0.9375
# Epoch 94/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1331 - accuracy: 0.9444
# Epoch 95/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1425 - accuracy: 0.9453
# Epoch 96/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1263 - accuracy: 0.9505
# Epoch 97/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1725 - accuracy: 0.9314
# Epoch 98/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.1665 - accuracy: 0.9297
# Epoch 99/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.1561 - accuracy: 0.9280
# Epoch 100/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1210 - accuracy: 0.9427
# Epoch 101/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1350 - accuracy: 0.9436
# Epoch 102/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1552 - accuracy: 0.9358
# Epoch 103/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.1289 - accuracy: 0.9462
# Epoch 104/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1819 - accuracy: 0.9288
# Epoch 105/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1870 - accuracy: 0.9297
# Epoch 106/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1352 - accuracy: 0.9418
# Epoch 107/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.1370 - accuracy: 0.9444
# Epoch 108/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1233 - accuracy: 0.9453
# Epoch 109/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.1235 - accuracy: 0.9384
# Epoch 110/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1303 - accuracy: 0.9427
# Epoch 111/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.1511 - accuracy: 0.9384
# Epoch 112/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1406 - accuracy: 0.9384
# Epoch 113/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.1239 - accuracy: 0.9566
# Epoch 114/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1465 - accuracy: 0.9488
# Epoch 115/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1114 - accuracy: 0.9497
# Epoch 116/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1238 - accuracy: 0.9462
# Epoch 117/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1088 - accuracy: 0.9566
# Epoch 118/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.1116 - accuracy: 0.9557
# Epoch 119/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0823 - accuracy: 0.9688
# Epoch 120/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0716 - accuracy: 0.9748
# Epoch 121/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.0819 - accuracy: 0.9661
# Epoch 122/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.0923 - accuracy: 0.9601
# Epoch 123/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1612 - accuracy: 0.9444
# Epoch 124/300
# 9/9 [==============================] - 120s 13s/step - loss: 0.1013 - accuracy: 0.9592
# Epoch 125/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1340 - accuracy: 0.9470
# Epoch 126/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1038 - accuracy: 0.9566
# Epoch 127/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1092 - accuracy: 0.9549
# Epoch 128/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1046 - accuracy: 0.9601
# Epoch 129/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0993 - accuracy: 0.9583
# Epoch 130/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1081 - accuracy: 0.9644
# Epoch 131/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1251 - accuracy: 0.9392
# Epoch 132/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.0968 - accuracy: 0.9566
# Epoch 133/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.0853 - accuracy: 0.9575
# Epoch 134/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.0983 - accuracy: 0.9566
# Epoch 135/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.0779 - accuracy: 0.9618
# Epoch 136/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.0958 - accuracy: 0.9601
# Epoch 137/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1064 - accuracy: 0.9661
# Epoch 138/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.1134 - accuracy: 0.9601
# Epoch 139/300
# 9/9 [==============================] - 121s 14s/step - loss: 0.1050 - accuracy: 0.9661
# Epoch 140/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.0923 - accuracy: 0.9688
# Epoch 141/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.0896 - accuracy: 0.9566
# Epoch 142/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.0937 - accuracy: 0.9557
# Epoch 143/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.0595 - accuracy: 0.9757
# Epoch 144/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.0581 - accuracy: 0.9783
# Epoch 145/300
# 9/9 [==============================] - 121s 14s/step - loss: 0.0794 - accuracy: 0.9670
# Epoch 146/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.0779 - accuracy: 0.9705
# Epoch 147/300
# 9/9 [==============================] - 119s 13s/step - loss: 0.1098 - accuracy: 0.9609
# Epoch 148/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.1216 - accuracy: 0.9592
# Epoch 149/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1020 - accuracy: 0.9601
# Epoch 150/300
# 9/9 [==============================] - 120s 13s/step - loss: 0.0887 - accuracy: 0.9714
# Epoch 151/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.0775 - accuracy: 0.9644
# Epoch 152/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.0608 - accuracy: 0.9731
# Epoch 153/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.0507 - accuracy: 0.9766
# Epoch 154/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.0442 - accuracy: 0.9844
# Epoch 155/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0422 - accuracy: 0.9852
# Epoch 156/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.0388 - accuracy: 0.9878
# Epoch 157/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0494 - accuracy: 0.9766
# Epoch 158/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0849 - accuracy: 0.9714
# Epoch 159/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.1392 - accuracy: 0.9540
# Epoch 160/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1218 - accuracy: 0.9566
# Epoch 161/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.1069 - accuracy: 0.9688
# Epoch 162/300
# 9/9 [==============================] - 122s 14s/step - loss: 0.1153 - accuracy: 0.9479
# Epoch 163/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1049 - accuracy: 0.9488
# Epoch 164/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.2434 - accuracy: 0.9245
# Epoch 165/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.1651 - accuracy: 0.9280
# Epoch 166/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1125 - accuracy: 0.9505
# Epoch 167/300
# 9/9 [==============================] - 121s 13s/step - loss: 0.1042 - accuracy: 0.9557
# Epoch 168/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.0928 - accuracy: 0.9601
# Epoch 169/300
# 9/9 [==============================] - 120s 13s/step - loss: 0.0784 - accuracy: 0.9696
# Epoch 170/300
# 9/9 [==============================] - 120s 13s/step - loss: 0.0863 - accuracy: 0.9635
# Epoch 171/300
# 9/9 [==============================] - 134s 15s/step - loss: 0.0797 - accuracy: 0.9696
# Epoch 172/300
# 9/9 [==============================] - 140s 15s/step - loss: 0.0539 - accuracy: 0.9722
# Epoch 173/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0737 - accuracy: 0.9705
# Epoch 174/300
# 9/9 [==============================] - 140s 16s/step - loss: 0.0781 - accuracy: 0.9635
# Epoch 175/300
# 9/9 [==============================] - 183s 20s/step - loss: 0.0635 - accuracy: 0.9714
# Epoch 176/300
# 9/9 [==============================] - 130s 14s/step - loss: 0.0844 - accuracy: 0.9688
# Epoch 177/300
# 9/9 [==============================] - 129s 14s/step - loss: 0.1009 - accuracy: 0.9549
# Epoch 178/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.1190 - accuracy: 0.9566
# Epoch 179/300
# 9/9 [==============================] - 129s 14s/step - loss: 0.1052 - accuracy: 0.9609
# Epoch 180/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0882 - accuracy: 0.9688
# Epoch 181/300
# 9/9 [==============================] - 123s 14s/step - loss: 0.0531 - accuracy: 0.9792
# Epoch 182/300
# 9/9 [==============================] - 144s 16s/step - loss: 0.0525 - accuracy: 0.9783
# Epoch 183/300
# 9/9 [==============================] - 141s 16s/step - loss: 0.0641 - accuracy: 0.9774
# Epoch 184/300
# 9/9 [==============================] - 129s 14s/step - loss: 0.0653 - accuracy: 0.9757
# Epoch 185/300
# 9/9 [==============================] - 160s 17s/step - loss: 0.0467 - accuracy: 0.9774
# Epoch 186/300
# 9/9 [==============================] - 143s 16s/step - loss: 0.0557 - accuracy: 0.9740
# Epoch 187/300
# 9/9 [==============================] - 148s 16s/step - loss: 0.0440 - accuracy: 0.9783
# Epoch 188/300
# 9/9 [==============================] - 183s 21s/step - loss: 0.0449 - accuracy: 0.9792
# Epoch 189/300
# 9/9 [==============================] - 194s 22s/step - loss: 0.0861 - accuracy: 0.9722
# Epoch 190/300
# 9/9 [==============================] - 248s 27s/step - loss: 0.0698 - accuracy: 0.9757
# Epoch 191/300
# 9/9 [==============================] - 278s 32s/step - loss: 0.0585 - accuracy: 0.9722
# Epoch 192/300
# 9/9 [==============================] - 272s 30s/step - loss: 0.0529 - accuracy: 0.9783
# Epoch 193/300
# 9/9 [==============================] - 286s 32s/step - loss: 0.0755 - accuracy: 0.9714
# Epoch 194/300
# 9/9 [==============================] - 276s 31s/step - loss: 0.0671 - accuracy: 0.9809
# Epoch 195/300
# 9/9 [==============================] - 305s 34s/step - loss: 0.0559 - accuracy: 0.9826
# Epoch 196/300
# 9/9 [==============================] - 236s 26s/step - loss: 0.0438 - accuracy: 0.9852
# Epoch 197/300
# 9/9 [==============================] - 234s 27s/step - loss: 0.0451 - accuracy: 0.9800
# Epoch 198/300
# 9/9 [==============================] - 266s 30s/step - loss: 0.0527 - accuracy: 0.9844
# Epoch 199/300
# 9/9 [==============================] - 270s 30s/step - loss: 0.0616 - accuracy: 0.9826
# Epoch 200/300
# 9/9 [==============================] - 229s 25s/step - loss: 0.0540 - accuracy: 0.9792
# Epoch 201/300
# 9/9 [==============================] - 205s 24s/step - loss: 0.0451 - accuracy: 0.9844
# Epoch 202/300
# 9/9 [==============================] - 162s 19s/step - loss: 0.0428 - accuracy: 0.9809
# Epoch 203/300
# 9/9 [==============================] - 225s 24s/step - loss: 0.0446 - accuracy: 0.9878
# Epoch 204/300
# 9/9 [==============================] - 211s 23s/step - loss: 0.1106 - accuracy: 0.9722
# Epoch 205/300
# 9/9 [==============================] - 210s 23s/step - loss: 0.1135 - accuracy: 0.9601
# Epoch 206/300
# 9/9 [==============================] - 206s 23s/step - loss: 0.0739 - accuracy: 0.9731
# Epoch 207/300
# 9/9 [==============================] - 208s 23s/step - loss: 0.0464 - accuracy: 0.9835
# Epoch 208/300
# 9/9 [==============================] - 206s 23s/step - loss: 0.0408 - accuracy: 0.9826
# Epoch 209/300
# 9/9 [==============================] - 207s 23s/step - loss: 0.0372 - accuracy: 0.9861
# Epoch 210/300
# 9/9 [==============================] - 223s 25s/step - loss: 0.0615 - accuracy: 0.9809
# Epoch 211/300
# 9/9 [==============================] - 265s 29s/step - loss: 0.0408 - accuracy: 0.9852
# Epoch 212/300
# 9/9 [==============================] - 282s 32s/step - loss: 0.0435 - accuracy: 0.9887
# Epoch 213/300
# 9/9 [==============================] - 281s 31s/step - loss: 0.0398 - accuracy: 0.9852
# Epoch 214/300
# 9/9 [==============================] - 234s 25s/step - loss: 0.0515 - accuracy: 0.9783
# Epoch 215/300
# 9/9 [==============================] - 244s 27s/step - loss: 0.0410 - accuracy: 0.9852
# Epoch 216/300
# 9/9 [==============================] - 192s 21s/step - loss: 0.0351 - accuracy: 0.9896
# Epoch 217/300
# 9/9 [==============================] - 206s 23s/step - loss: 0.0240 - accuracy: 0.9922
# Epoch 218/300
# 9/9 [==============================] - 233s 26s/step - loss: 0.0403 - accuracy: 0.9844
# Epoch 219/300
# 9/9 [==============================] - 186s 20s/step - loss: 0.0635 - accuracy: 0.9731
# Epoch 220/300
# 9/9 [==============================] - 178s 20s/step - loss: 0.1634 - accuracy: 0.9592
# Epoch 221/300
# 9/9 [==============================] - 178s 21s/step - loss: 0.1676 - accuracy: 0.9470
# Epoch 222/300
# 9/9 [==============================] - 208s 23s/step - loss: 0.1146 - accuracy: 0.9688
# Epoch 223/300
# 9/9 [==============================] - 212s 24s/step - loss: 0.0622 - accuracy: 0.9774
# Epoch 224/300
# 9/9 [==============================] - 206s 23s/step - loss: 0.0560 - accuracy: 0.9844
# Epoch 225/300
# 9/9 [==============================] - 209s 23s/step - loss: 0.0580 - accuracy: 0.9774
# Epoch 226/300
# 9/9 [==============================] - 209s 23s/step - loss: 0.0533 - accuracy: 0.9809
# Epoch 227/300
# 9/9 [==============================] - 231s 26s/step - loss: 0.0587 - accuracy: 0.9731
# Epoch 228/300
# 9/9 [==============================] - 286s 32s/step - loss: 0.0553 - accuracy: 0.9757
# Epoch 229/300
# 9/9 [==============================] - 287s 32s/step - loss: 0.0481 - accuracy: 0.9774
# Epoch 230/300
# 9/9 [==============================] - 247s 27s/step - loss: 0.0276 - accuracy: 0.9922
# Epoch 231/300
# 9/9 [==============================] - 250s 28s/step - loss: 0.0298 - accuracy: 0.9905
# Epoch 232/300
# 9/9 [==============================] - 219s 24s/step - loss: 0.0247 - accuracy: 0.9913
# Epoch 233/300
# 9/9 [==============================] - 214s 24s/step - loss: 0.0235 - accuracy: 0.9931
# Epoch 234/300
# 9/9 [==============================] - 217s 24s/step - loss: 0.0231 - accuracy: 0.9931
# Epoch 235/300
# 9/9 [==============================] - 215s 24s/step - loss: 0.0210 - accuracy: 0.9939
# Epoch 236/300
# 9/9 [==============================] - 211s 23s/step - loss: 0.0230 - accuracy: 0.9922
# Epoch 237/300
# 9/9 [==============================] - 201s 22s/step - loss: 0.0406 - accuracy: 0.9861
# Epoch 238/300
# 9/9 [==============================] - 174s 19s/step - loss: 0.0386 - accuracy: 0.9905
# Epoch 239/300
# 9/9 [==============================] - 175s 19s/step - loss: 0.0513 - accuracy: 0.9740
# Epoch 240/300
# 9/9 [==============================] - 174s 19s/step - loss: 0.0696 - accuracy: 0.9722
# Epoch 241/300
# 9/9 [==============================] - 174s 19s/step - loss: 0.0560 - accuracy: 0.9748
# Epoch 242/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0638 - accuracy: 0.9783
# Epoch 243/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0675 - accuracy: 0.9800
# Epoch 244/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0428 - accuracy: 0.9844
# Epoch 245/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0713 - accuracy: 0.9688
# Epoch 246/300
# 9/9 [==============================] - 128s 14s/step - loss: 0.0559 - accuracy: 0.9861
# Epoch 247/300
# 9/9 [==============================] - 129s 14s/step - loss: 0.0569 - accuracy: 0.9852
# Epoch 248/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0450 - accuracy: 0.9861
# Epoch 249/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0477 - accuracy: 0.9800
# Epoch 250/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0241 - accuracy: 0.9948
# Epoch 251/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0355 - accuracy: 0.9844
# Epoch 252/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0312 - accuracy: 0.9931
# Epoch 253/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0407 - accuracy: 0.9922
# Epoch 254/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0673 - accuracy: 0.9844
# Epoch 255/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0295 - accuracy: 0.9931
# Epoch 256/300
# 9/9 [==============================] - 128s 14s/step - loss: 0.0404 - accuracy: 0.9878
# Epoch 257/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0423 - accuracy: 0.9887
# Epoch 258/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0748 - accuracy: 0.9766
# Epoch 259/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0561 - accuracy: 0.9844
# Epoch 260/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0400 - accuracy: 0.9878
# Epoch 261/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0403 - accuracy: 0.9878
# Epoch 262/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0287 - accuracy: 0.9939
# Epoch 263/300
# 9/9 [==============================] - 128s 14s/step - loss: 0.0587 - accuracy: 0.9878
# Epoch 264/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0249 - accuracy: 0.9913
# Epoch 265/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0295 - accuracy: 0.9922
# Epoch 266/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0306 - accuracy: 0.9887
# Epoch 267/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0364 - accuracy: 0.9870
# Epoch 268/300
# 9/9 [==============================] - 122s 13s/step - loss: 0.0421 - accuracy: 0.9887
# Epoch 269/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0192 - accuracy: 0.9948
# Epoch 270/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0232 - accuracy: 0.9957
# Epoch 271/300
# 9/9 [==============================] - 128s 14s/step - loss: 0.0160 - accuracy: 0.9974
# Epoch 272/300
# 9/9 [==============================] - 131s 15s/step - loss: 0.0192 - accuracy: 0.9922
# Epoch 273/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0172 - accuracy: 0.9948
# Epoch 274/300
# 9/9 [==============================] - 130s 14s/step - loss: 0.0112 - accuracy: 0.9965
# Epoch 275/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0224 - accuracy: 0.9922
# Epoch 276/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0289 - accuracy: 0.9905
# Epoch 277/300
# 9/9 [==============================] - 128s 14s/step - loss: 0.0592 - accuracy: 0.9818
# Epoch 278/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0224 - accuracy: 0.9931
# Epoch 279/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0406 - accuracy: 0.9896
# Epoch 280/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0285 - accuracy: 0.9939
# Epoch 281/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0240 - accuracy: 0.9913
# Epoch 282/300
# 9/9 [==============================] - 129s 14s/step - loss: 0.0395 - accuracy: 0.9870
# Epoch 283/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0527 - accuracy: 0.9896
# Epoch 284/300
# 9/9 [==============================] - 129s 14s/step - loss: 0.0362 - accuracy: 0.9887
# Epoch 285/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0225 - accuracy: 0.9957
# Epoch 286/300
# 9/9 [==============================] - 277s 32s/step - loss: 0.0255 - accuracy: 0.9965
# Epoch 287/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0126 - accuracy: 0.9965
# Epoch 288/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0157 - accuracy: 0.9957
# Epoch 289/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0113 - accuracy: 0.9965
# Epoch 290/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0079 - accuracy: 0.9983
# Epoch 291/300
# 9/9 [==============================] - 129s 14s/step - loss: 0.0082 - accuracy: 0.9991
# Epoch 292/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0059 - accuracy: 0.9991
# Epoch 293/300
# 9/9 [==============================] - 128s 14s/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 294/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 295/300
# 9/9 [==============================] - 128s 14s/step - loss: 0.0076 - accuracy: 0.9983
# Epoch 296/300
# 9/9 [==============================] - 125s 14s/step - loss: 0.0039 - accuracy: 0.9991
# Epoch 297/300
# 9/9 [==============================] - 127s 14s/step - loss: 0.0064 - accuracy: 0.9991
# Epoch 298/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0036 - accuracy: 0.9991
# Epoch 299/300
# 9/9 [==============================] - 126s 14s/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 300/300
# 9/9 [==============================] - 124s 14s/step - loss: 0.0074 - accuracy: 0.9965
# /home/ancao/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ancao/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Average Train Accuracy: 0.9991319444444444
# Average Train AUC Score: 0.9999976423620389
# Average Train MCC Score: 0.9986245809478488
#
#
# Average Train Classification Report:
#               precision    recall  f1-score   support
#
#     artifact    1.00000   1.00000   1.00000       128
#     extrahls    1.00000   1.00000   1.00000        41
#   extrastole    1.00000   1.00000   1.00000        70
#       murmur    1.00000   0.99664   0.99832       298
#       normal    0.99838   1.00000   0.99919       615
#
#     accuracy                        0.99913      1152
#    macro avg    0.99968   0.99933   0.99950      1152
# weighted avg    0.99913   0.99913   0.99913      1152
#
# Average Test Accuracy: 0.7370242214532872
# Average Test AUC Score: 0.8624562259139747
# Average Test MCC Score: 0.5738580379859861
#
#
# Average Test Classification Report:
#               precision    recall  f1-score   support
#
#     artifact    0.96875   0.96875   0.96875        32
#     extrahls    0.66667   0.20000   0.30769        10
#   extrastole    0.44444   0.22222   0.29630        18
#       murmur    0.88571   0.41333   0.56364        75
#       normal    0.69048   0.94156   0.79670       154
#
#     accuracy                        0.73702       289
#    macro avg    0.73121   0.54917   0.58662       289
# weighted avg    0.75581   0.73702   0.70718       289

# %%
from keras.models import load_model
model.save('model_CNN-LSTM.h5')

# %%
import os
import glob
import numpy as np
from tqdm import tqdm
import itertools
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Audio
import librosa
import librosa.display

# Scikit learn
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_auc_score, matthews_corrcoef
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import shuffle
from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.layers import Input, add, Flatten, Dense, BatchNormalization, Dropout, LSTM, GRU
from tensorflow.keras.layers import GlobalMaxPooling1D, GlobalMaxPooling2D, Activation, LeakyReLU, ReLU, MaxPooling1D

# Keras
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
# Keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Flatten, BatchNormalization, Reshape
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Conv1D

from tensorflow.keras.utils import to_categorical

# TensorFlow
from tensorflow.keras.utils import to_categorical

# Ignore warnings
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

dataset = []
for folder in ["Heartbeat_Sounds/set_a/**","Heartbeat_Sounds/set_b/**"]:
    for filename in glob.iglob(folder):
        if os.path.exists(filename):
            label = os.path.basename(filename).split("_")[0]
            duration = librosa.get_duration(filename=filename)
            # skip audio smaller than 3 secs
            if duration>=3:
                slice_size = 3
                iterations = int((duration-slice_size)/(slice_size-1))
                iterations += 1
#                 initial_offset = (duration % slice_size)/2
                initial_offset = (duration - ((iterations*(slice_size-1))+1))/2
                if label not in ["Aunlabelledtest", "Bunlabelledtest"]:
                    for i in range(iterations):
                        offset = initial_offset + i*(slice_size-1)
                        
                        dataset.append({
                                "filename": filename,
                                "label": label,
                                "offset": offset
                            })
                       
                        
dataset = pd.DataFrame(dataset)
dataset = shuffle(dataset, random_state=42)
dataset.info()

# Function to extract features
def extract_features(audio_path, offset):
    y, sr = librosa.load(audio_path, offset=offset, duration=3)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=2048, hop_length=512, n_mels=128)
    mfccs = librosa.feature.mfcc(S=librosa.power_to_db(S), n_mfcc=40)
    return mfccs

# Extract features for all data points
x_data = []
for idx in tqdm(range(len(dataset))):
    x_data.append(extract_features(dataset.filename.iloc[idx], dataset.offset.iloc[idx]))

# Convert to numpy array
x_data = np.asarray(x_data)

# Encode Labels
encoder = LabelEncoder()
encoder.fit(dataset.label)
y_data = encoder.transform(dataset.label)

unique_labels = dataset['label'].unique()
num_classes = len(unique_labels)

# Compute class weights
class_weights = class_weight.compute_class_weight(class_weight="balanced", classes=np.unique(y_data), y=y_data)

y_data_one_hot = to_categorical(y_data, num_classes=num_classes)


# Initialize StratifiedKFold with train_size and test_size
kfold = StratifiedShuffleSplit(n_splits=10, test_size=0.2, random_state=42)

# Initialize lists to store results for each fold
train_accuracies = []
test_accuracies = []
train_auc_scores = []
test_auc_scores = []
train_mcc_scores = []
test_mcc_scores = []
train_conf_matrices = []
test_conf_matrices = []
train_class_reports = []
test_class_reports = []
cm_test_normalized = []
report_test_list = []
cm_test_normalized_list = []

# Open the common results file in 'w' mode to overwrite existing content
with open('results_heartSound/all_folds_lstm5_results200.txt', 'w') as common_file:
    # Split the indices instead of the dataset
    for fold, (train_index, test_index) in enumerate(kfold.split(x_data, y_data_one_hot), 1):
        x_train_fold, x_test_fold = x_data[train_index], x_data[test_index]
        y_train_fold, y_test_fold = y_data_one_hot[train_index], y_data_one_hot[test_index]

        model = Sequential()

        model.add(Conv1D(2048, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(40, 130)))
        model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
        model.add(BatchNormalization())

        model.add(Conv1D(1024, kernel_size=5, strides=1, padding='same', activation='relu'))
        model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
        model.add(BatchNormalization())  # This line was corrected from lstm_model to model

        model.add(Conv1D(512, kernel_size=5, strides=1, padding='same', activation='relu'))
        model.add(MaxPooling1D(pool_size=2, strides=2, padding='same'))
        model.add(BatchNormalization())

        model.add(LSTM(256, return_sequences=True))
        model.add(LSTM(128))

        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.5))

        model.add(Dense(32, activation='relu'))
        model.add(Dropout(0.5))

        model.add(Dense(num_classes, activation='softmax'))


        model.summary()

        # Compile the model
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        your_epochs = 100  # You can choose an appropriate number of epochs
        your_batch_size = 64  # You can choose an appropriate batch size

        # Train and evaluate the model for the current fold
        model.fit(x_train_fold, y_train_fold, epochs=your_epochs, batch_size=your_batch_size)
        y_pred_train = model.predict(x_train_fold)
        y_pred_test = model.predict(x_test_fold)
        
        y_pred_test_labels = np.argmax(y_pred_test, axis=1)
        report_test = classification_report(np.argmax(y_test_fold, axis=1), y_pred_test_labels, output_dict=True)

        # Calculate metrics for train set
        train_accuracy = accuracy_score(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1))
        train_auc = roc_auc_score(y_train_fold, y_pred_train, multi_class='ovr')
        train_mcc = matthews_corrcoef(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1))
        train_cm = confusion_matrix(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1))
        train_class_report = classification_report(np.argmax(y_train_fold, axis=1), np.argmax(y_pred_train, axis=1), target_names=encoder.classes_)

        # Calculate metrics for test set
        test_accuracy = accuracy_score(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))
        test_auc = roc_auc_score(y_test_fold, y_pred_test, multi_class='ovr')
        test_mcc = matthews_corrcoef(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))
        test_cm = confusion_matrix(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))
        test_class_report = classification_report(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1), target_names=encoder.classes_)

        # Inside the loop where you append accuracies to lists
        train_accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)

        # Calculate std for train and test accuracies
        train_accuracy_std = np.std(train_accuracies)
        test_accuracy_std = np.std(test_accuracies)


        # Save results to the common text file for both train and test sets
        common_file.write(f'Fold {fold} Results:\n')
        common_file.write(f'Train Accuracy: {train_accuracy} (std: {train_accuracy_std})\n')
        common_file.write(f'Train AUC Score: {train_auc}\n')
        common_file.write(f'Train MCC Score: {train_mcc}\n\n')
        common_file.write('Train Confusion Matrix:\n')
        common_file.write(str(train_cm))
        common_file.write('\n\nTrain Classification Report:\n')
        common_file.write(train_class_report)

        common_file.write(f'\n\nTest Accuracy: {test_accuracy} (std: {test_accuracy_std})\n')
        common_file.write(f'Test AUC Score: {test_auc}\n')
        common_file.write(f'Test MCC Score: {test_mcc}\n\n')
        common_file.write('Test Confusion Matrix:\n')
        common_file.write(str(test_cm))
        common_file.write('\n\nTest Classification Report:\n')
        common_file.write(test_class_report)
        
        # Print a separator between folds
        common_file.write("\n" + "="*40 + "\n")
        
        # Calculate average metrics for train set
        avg_train_accuracy = np.mean(train_accuracies)
        avg_train_auc = np.mean(train_auc_scores)
        avg_train_mcc = np.mean(train_mcc_scores)
        avg_train_conf_matrix = np.mean(train_conf_matrices, axis=0)  # Average confusion matrix

        # Convert continuous probabilities to class labels using argmax
        y_pred_train_class = np.argmax(y_pred_train, axis=1)

        # Calculate average metrics for test set
        avg_test_accuracy = np.mean(test_accuracies)
        avg_test_auc = np.mean(test_auc_scores)
        avg_test_mcc = np.mean(test_mcc_scores)
        avg_test_conf_matrix = np.mean(test_conf_matrices, axis=0)  # Average confusion matrix

        # Convert continuous probabilities to class labels using argmax
        y_pred_test_class = np.argmax(y_pred_test, axis=1)
        
        # Calculate average results for train set
        avg_train_class_report = classification_report(np.argmax(y_train_fold, axis=1), y_pred_train_class, target_names=encoder.classes_)

        # Calculate average results for test set
        avg_test_class_report = classification_report(np.argmax(y_test_fold, axis=1), y_pred_test_class, target_names=encoder.classes_)


        # Inside the loop where you plot confusion matrices
        plt.figure()
        train_cm = confusion_matrix(np.argmax(y_train_fold, axis=1), y_pred_train.argmax(axis=1))

        # Round each value in the confusion matrix to 5 decimal places
        rounded_train_cm = np.round(train_cm / np.sum(train_cm, axis=1)[:, np.newaxis], 5)

        sns.heatmap(rounded_train_cm, annot=True, fmt='.5f', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
        plt.title(f'Train Confusion Matrix - Fold {fold}')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.savefig(f'LSTM200/train_confusion_matrix_fold_{fold}.png')
        plt.close()

        # Inside the loop where you plot confusion matrices
        plt.figure()
        test_cm = confusion_matrix(np.argmax(y_test_fold, axis=1), y_pred_test.argmax(axis=1))

        # Round each value in the confusion matrix to 5 decimal places
        rounded_test_cm = np.round(test_cm / np.sum(test_cm, axis=1)[:, np.newaxis], 5)

        sns.heatmap(rounded_test_cm, annot=True, fmt='.5f', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
        plt.title(f'Test Confusion Matrix - Fold {fold}')
        plt.xlabel('Predicted')
        plt.ylabel('True')
        plt.savefig(f'LSTM200/test_confusion_matrix_fold_{fold}.png')
        plt.close()

        # Inside the loop where you append results to lists
        train_accuracies.append(train_accuracy)
        test_accuracies.append(test_accuracy)
        train_auc_scores.append(train_auc)
        test_auc_scores.append(test_auc)
        train_mcc_scores.append(train_mcc)
        test_mcc_scores.append(test_mcc)
        train_conf_matrices.append(train_cm)
        test_conf_matrices.append(test_cm)
        train_class_reports.append(train_class_report)
        test_class_reports.append(test_class_report)
        
        # Print a separator between folds
        common_file.write("\n" + "="*40 + "\n")
        
        # Append classification report and confusion matrix to lists
        report_test_list.append(report_test)
        cm_test_normalized_list.append(cm_test_normalized)
        

    # Calculate average metrics for train set
    avg_train_accuracy = np.mean(train_accuracies)
    avg_train_auc = np.mean(train_auc_scores)
    avg_train_mcc = np.mean(train_mcc_scores)

    # Reshape y_train_fold to (num_samples, num_classes)
    y_train_fold_reshaped = to_categorical(y_train_fold, num_classes=len(encoder.classes_))

    # Convert predictions to one-hot encoding
    y_pred_train_one_hot = to_categorical(np.argmax(y_pred_train, axis=1), num_classes=len(encoder.classes_))

    # Calculate average confusion matrix for train set
    avg_train_conf_matrix = np.mean(train_conf_matrices, axis=0).astype(int)


    # Calculate average classification report for train set
    avg_train_class_report = classification_report(
        np.argmax(y_train_fold, axis=1), 
        np.argmax(y_pred_train_one_hot, axis=1), 
        target_names=encoder.classes_, 
        digits=5
    )
    

    # Calculate average metrics for test set
    avg_test_accuracy = np.mean(test_accuracies)
    avg_test_auc = np.mean(test_auc_scores)
    avg_test_mcc = np.mean(test_mcc_scores)

    # Reshape y_test_fold to (num_samples, num_classes)
    y_test_fold_reshaped = to_categorical(y_test_fold, num_classes=len(encoder.classes_))

    # Convert predictions to one-hot encoding
    y_pred_test_one_hot = to_categorical(np.argmax(y_pred_test, axis=1), num_classes=len(encoder.classes_))

    # Calculate average confusion matrix for test set
    avg_test_conf_matrix = np.mean(test_conf_matrices, axis=0).astype(int)

    # Calculate average classification report for test set
    avg_test_class_report = classification_report(
        np.argmax(y_test_fold, axis=1), 
        np.argmax(y_pred_test_one_hot, axis=1), 
        target_names=encoder.classes_, 
        digits=5
    )

    # Inside the loop where you plot the average confusion matrix for the test set
    avg_cm_test_normalized = np.mean(cm_test_normalized_list, axis=0)
    plt.figure()

    avg_test_cm = confusion_matrix(np.argmax(y_test_fold, axis=1), np.argmax(y_pred_test, axis=1))

    # Normalize the confusion matrix by dividing each value by the sum of its row
    normalized_avg_test_cm = avg_test_cm / avg_test_cm.sum(axis=1)[:, np.newaxis]

    # Plot confusion matrix for the average test set
    plt.figure()
    sns.heatmap(normalized_avg_test_cm, annot=True, fmt='.5f', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
    plt.title(f'Average Test Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.savefig('LSTM200/average_test_confusion_matrix.png')
    plt.close()



    # Save average results to the common text file
    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Test Accuracy: {avg_test_accuracy:.5f} (std: {np.std(test_accuracies):.5f})\n')
    common_file.write(f'Average Test AUC Score: {avg_test_auc:.5f}\n')
    common_file.write(f'Average Test MCC Score: {avg_test_mcc:.5f}\n\n')
    common_file.write('Average Test Confusion Matrix:\n')
    common_file.write(str(avg_cm_test_normalized.round(5).astype(int)))  # Display confusion matrix with 5 decimal places
    common_file.write("\n\nAverage Test Classification Report:\n")
    common_file.write(str(avg_test_class_report))


    # Print and write the average results to the common text file
    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Test Accuracy: {avg_test_accuracy:.5f} (std: {np.std(test_accuracies):.5f})\n')
    common_file.write(f'Average Test AUC Score: {avg_test_auc:.5f}\n')
    common_file.write(f'Average Test MCC Score: {avg_test_mcc:.5f}\n\n')
    common_file.write('Average Test Confusion Matrix:\n')
    common_file.write(str(avg_cm_test_normalized.round(5).astype(int)))  # Display confusion matrix with 5 decimal places
    common_file.write("\n\nAverage Test Classification Report:\n")
    common_file.write(str(avg_test_class_report))


    # Print and write the average results to the common text file
    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Train Accuracy: {avg_train_accuracy} (std: {np.std(train_accuracies)})\n')
    common_file.write(f'Average Train AUC Score: {avg_train_auc}\n')
    common_file.write(f'Average Train MCC Score: {avg_train_mcc}\n\n')
    common_file.write('Average Train Confusion Matrix:\n')
    common_file.write(str(avg_train_conf_matrix.astype(int)))
    common_file.write("\n\nAverage Train Classification Report:\n")
    common_file.write(str(avg_train_class_report))

    common_file.write("\n" + "="*40 + "\n")
    common_file.write(f'Average Test Accuracy: {avg_test_accuracy} (std: {np.std(test_accuracies)})\n')
    common_file.write(f'Average Test AUC Score: {avg_test_auc}\n')
    common_file.write(f'Average Test MCC Score: {avg_test_mcc}\n\n')
    common_file.write('Average Test Confusion Matrix:\n')
    common_file.write(str(avg_test_conf_matrix.astype(int)))
    common_file.write("\n\nAverage Test Classification Report:\n")
    common_file.write(str(avg_test_class_report))
        
    # Print average results for train set
    print(f'Average Train Accuracy: {avg_train_accuracy}')
    print(f'Average Train AUC Score: {avg_train_auc}')
    print(f'Average Train MCC Score: {avg_train_mcc} \n')
    print("\nAverage Train Classification Report:")
    print(avg_train_class_report)

    # Print average results for test set
    print(f'Average Test Accuracy: {avg_test_accuracy}')
    print(f'Average Test AUC Score: {avg_test_auc}')
    print(f'Average Test MCC Score: {avg_test_mcc} \n')
    print("\nAverage Test Classification Report:")
    print(avg_test_class_report)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1441 entries, 168 to 1126
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  1441 non-null   object
#  1   label     1441 non-null   object
#  2   offset    1441 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 45.0+ KB
# 100%|██████████| 1441/1441 [00:30<00:00, 46.74it/s]
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_12 (Conv1D)          (None, 40, 2048)          1333248
#
#  max_pooling1d_12 (MaxPooli  (None, 20, 2048)          0
#  ng1D)
#
#  batch_normalization_12 (Ba  (None, 20, 2048)          8192
#  tchNormalization)
#
#  conv1d_13 (Conv1D)          (None, 20, 1024)          10486784
#
#  max_pooling1d_13 (MaxPooli  (None, 10, 1024)          0
#  ng1D)
#
#  batch_normalization_13 (Ba  (None, 10, 1024)          4096
#  tchNormalization)
#
#  conv1d_14 (Conv1D)          (None, 10, 512)           2621952
#
#  max_pooling1d_14 (MaxPooli  (None, 5, 512)            0
#  ng1D)
#
#  batch_normalization_14 (Ba  (None, 5, 512)            2048
#  tchNormalization)
#
#  lstm_8 (LSTM)               (None, 5, 256)            787456
#
#  lstm_9 (LSTM)               (None, 128)               197120
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_14 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 15451397 (58.94 MB)
# Trainable params: 15444229 (58.92 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________
# Epoch 1/100
# 18/18 [==============================] - 91s 4s/step - loss: 1.3458 - accuracy: 0.4375
# Epoch 2/100
# 18/18 [==============================] - 77s 4s/step - loss: 1.1542 - accuracy: 0.5512
# Epoch 3/100
# 18/18 [==============================] - 71s 4s/step - loss: 1.0309 - accuracy: 0.6146
# Epoch 4/100
# 18/18 [==============================] - 61s 3s/step - loss: 1.0283 - accuracy: 0.6233
# Epoch 5/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.9850 - accuracy: 0.6372
# Epoch 6/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.9672 - accuracy: 0.6450
# Epoch 7/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.9563 - accuracy: 0.6571
# Epoch 8/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.8767 - accuracy: 0.6875
# Epoch 9/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.8587 - accuracy: 0.6936
# Epoch 10/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.8503 - accuracy: 0.6953
# Epoch 11/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.8056 - accuracy: 0.7179
# Epoch 12/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.8398 - accuracy: 0.7031
# Epoch 13/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.8366 - accuracy: 0.7049
# Epoch 14/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.7902 - accuracy: 0.7240
# Epoch 15/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.8241 - accuracy: 0.7049
# Epoch 16/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.7735 - accuracy: 0.7344
# Epoch 17/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.7634 - accuracy: 0.7318
# Epoch 18/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.7260 - accuracy: 0.7387
# Epoch 19/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.7531 - accuracy: 0.7309
# Epoch 20/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.7130 - accuracy: 0.7457
# Epoch 21/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.7289 - accuracy: 0.7344
# Epoch 22/100
# 18/18 [==============================] - 53s 3s/step - loss: 0.7219 - accuracy: 0.7439
# Epoch 23/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.6673 - accuracy: 0.7569
# Epoch 24/100
# 18/18 [==============================] - 59s 3s/step - loss: 0.6729 - accuracy: 0.7769
# Epoch 25/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.6572 - accuracy: 0.7682
# Epoch 26/100
# 18/18 [==============================] - 65s 4s/step - loss: 0.6405 - accuracy: 0.7743
# Epoch 27/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.6408 - accuracy: 0.7674
# Epoch 28/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.6211 - accuracy: 0.7847
# Epoch 29/100
# 18/18 [==============================] - 45s 2s/step - loss: 0.6182 - accuracy: 0.7726
# Epoch 30/100
# 18/18 [==============================] - 53s 3s/step - loss: 0.6059 - accuracy: 0.7786
# Epoch 31/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.5529 - accuracy: 0.7873
# Epoch 32/100
# 18/18 [==============================] - 58s 3s/step - loss: 0.5956 - accuracy: 0.7882
# Epoch 33/100
# 18/18 [==============================] - 51s 3s/step - loss: 0.6648 - accuracy: 0.7622
# Epoch 34/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.6217 - accuracy: 0.7821
# Epoch 35/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.5993 - accuracy: 0.7743
# Epoch 36/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.5943 - accuracy: 0.7778
# Epoch 37/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.5416 - accuracy: 0.7986
# Epoch 38/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.4978 - accuracy: 0.8047
# Epoch 39/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.5058 - accuracy: 0.8151
# Epoch 40/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.4568 - accuracy: 0.8090
# Epoch 41/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.4649 - accuracy: 0.8333
# Epoch 42/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.4325 - accuracy: 0.8307
# Epoch 43/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4244 - accuracy: 0.8550
# Epoch 44/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.3773 - accuracy: 0.8438
# Epoch 45/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.3904 - accuracy: 0.8542
# Epoch 46/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.4073 - accuracy: 0.8429
# Epoch 47/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.3684 - accuracy: 0.8524
# Epoch 48/100
# 18/18 [==============================] - 70s 4s/step - loss: 0.3388 - accuracy: 0.8620
# Epoch 49/100
# 18/18 [==============================] - 73s 4s/step - loss: 0.3493 - accuracy: 0.8524
# Epoch 50/100
# 18/18 [==============================] - 57s 3s/step - loss: 0.3449 - accuracy: 0.8637
# Epoch 51/100
# 18/18 [==============================] - 51s 3s/step - loss: 0.3235 - accuracy: 0.8715
# Epoch 52/100
# 18/18 [==============================] - 45s 2s/step - loss: 0.3673 - accuracy: 0.8507
# Epoch 53/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.4001 - accuracy: 0.8542
# Epoch 54/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.3125 - accuracy: 0.8655
# Epoch 55/100
# 18/18 [==============================] - 48s 3s/step - loss: 0.3022 - accuracy: 0.8724
# Epoch 56/100
# 18/18 [==============================] - 54s 3s/step - loss: 0.3500 - accuracy: 0.8620
# Epoch 57/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.3136 - accuracy: 0.8689
# Epoch 58/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.2733 - accuracy: 0.8811
# Epoch 59/100
# 18/18 [==============================] - 53s 3s/step - loss: 0.2750 - accuracy: 0.8785
# Epoch 60/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.2929 - accuracy: 0.8793
# Epoch 61/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.3216 - accuracy: 0.8637
# Epoch 62/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.3719 - accuracy: 0.8655
# Epoch 63/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.3101 - accuracy: 0.8681
# Epoch 64/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.2495 - accuracy: 0.8898
# Epoch 65/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.2649 - accuracy: 0.8837
# Epoch 66/100
# 18/18 [==============================] - 48s 3s/step - loss: 0.2927 - accuracy: 0.8785
# Epoch 67/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.2307 - accuracy: 0.8915
# Epoch 68/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.2151 - accuracy: 0.9097
# Epoch 69/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.2049 - accuracy: 0.9106
# Epoch 70/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.1907 - accuracy: 0.9236
# Epoch 71/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.1980 - accuracy: 0.9141
# Epoch 72/100
# 18/18 [==============================] - 45s 3s/step - loss: 0.1876 - accuracy: 0.9262
# Epoch 73/100
# 18/18 [==============================] - 51s 3s/step - loss: 0.1739 - accuracy: 0.9262
# Epoch 74/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.2102 - accuracy: 0.9193
# Epoch 75/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.2169 - accuracy: 0.9123
# Epoch 76/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.1685 - accuracy: 0.9358
# Epoch 77/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2321 - accuracy: 0.9062
# Epoch 78/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.1720 - accuracy: 0.9253
# Epoch 79/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.1846 - accuracy: 0.9245
# Epoch 80/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.2481 - accuracy: 0.9089
# Epoch 81/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.2610 - accuracy: 0.9115
# Epoch 82/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.1900 - accuracy: 0.9210
# Epoch 83/100
# 18/18 [==============================] - 36s 2s/step - loss: 0.1710 - accuracy: 0.9375
# Epoch 84/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.1947 - accuracy: 0.9219
# Epoch 85/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1930 - accuracy: 0.9297
# Epoch 86/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.1888 - accuracy: 0.9201
# Epoch 87/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.2477 - accuracy: 0.9089
# Epoch 88/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1818 - accuracy: 0.9280
# Epoch 89/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.2019 - accuracy: 0.9349
# Epoch 90/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2108 - accuracy: 0.9236
# Epoch 91/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.1710 - accuracy: 0.9523
# Epoch 92/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.1729 - accuracy: 0.9392
# Epoch 93/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.1368 - accuracy: 0.9462
# Epoch 94/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.1125 - accuracy: 0.9514
# Epoch 95/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.1012 - accuracy: 0.9540
# Epoch 96/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1250 - accuracy: 0.9635
# Epoch 97/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1147 - accuracy: 0.9618
# Epoch 98/100
# 18/18 [==============================] - 36s 2s/step - loss: 0.1281 - accuracy: 0.9514
# Epoch 99/100
# 18/18 [==============================] - 36s 2s/step - loss: 0.2148 - accuracy: 0.9375
# Epoch 100/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.1379 - accuracy: 0.9418
# 36/36 [==============================] - 15s 291ms/step
# 10/10 [==============================] - 6s 260ms/step
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_15 (Conv1D)          (None, 40, 2048)          1333248
#
#  max_pooling1d_15 (MaxPooli  (None, 20, 2048)          0
#  ng1D)
#
#  batch_normalization_15 (Ba  (None, 20, 2048)          8192
#  tchNormalization)
#
#  conv1d_16 (Conv1D)          (None, 20, 1024)          10486784
#
#  max_pooling1d_16 (MaxPooli  (None, 10, 1024)          0
#  ng1D)
#
#  batch_normalization_16 (Ba  (None, 10, 1024)          4096
#  tchNormalization)
#
#  conv1d_17 (Conv1D)          (None, 10, 512)           2621952
#
#  max_pooling1d_17 (MaxPooli  (None, 5, 512)            0
#  ng1D)
#
#  batch_normalization_17 (Ba  (None, 5, 512)            2048
#  tchNormalization)
#
#  lstm_10 (LSTM)              (None, 5, 256)            787456
#
#  lstm_11 (LSTM)              (None, 128)               197120
#
#  dense_15 (Dense)            (None, 64)                8256
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_16 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_17 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 15451397 (58.94 MB)
# Trainable params: 15444229 (58.92 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________
# Epoch 1/100
# 18/18 [==============================] - 57s 2s/step - loss: 1.2674 - accuracy: 0.5165
# Epoch 2/100
# 18/18 [==============================] - 40s 2s/step - loss: 1.0903 - accuracy: 0.5964
# Epoch 3/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.9922 - accuracy: 0.6233
# Epoch 4/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.9650 - accuracy: 0.6250
# Epoch 5/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.8943 - accuracy: 0.6658
# Epoch 6/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.8771 - accuracy: 0.6736
# Epoch 7/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.8982 - accuracy: 0.6589
# Epoch 8/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.8829 - accuracy: 0.6649
# Epoch 9/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.8800 - accuracy: 0.6788
# Epoch 10/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.8459 - accuracy: 0.6962
# Epoch 11/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.8084 - accuracy: 0.7040
# Epoch 12/100
# 18/18 [==============================] - 34s 2s/step - loss: 0.8361 - accuracy: 0.6979
# Epoch 13/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7781 - accuracy: 0.7205
# Epoch 14/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7686 - accuracy: 0.7222
# Epoch 15/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7174 - accuracy: 0.7405
# Epoch 16/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7879 - accuracy: 0.7118
# Epoch 17/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.7717 - accuracy: 0.6997
# Epoch 18/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.7196 - accuracy: 0.7439
# Epoch 19/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7111 - accuracy: 0.7352
# Epoch 20/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7585 - accuracy: 0.7378
# Epoch 21/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7162 - accuracy: 0.7465
# Epoch 22/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.7104 - accuracy: 0.7387
# Epoch 23/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.7467 - accuracy: 0.7031
# Epoch 24/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.7093 - accuracy: 0.7370
# Epoch 25/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6892 - accuracy: 0.7483
# Epoch 26/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6355 - accuracy: 0.7569
# Epoch 27/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6379 - accuracy: 0.7569
# Epoch 28/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.5812 - accuracy: 0.7769
# Epoch 29/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6256 - accuracy: 0.7543
# Epoch 30/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6224 - accuracy: 0.7526
# Epoch 31/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6500 - accuracy: 0.7457
# Epoch 32/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6144 - accuracy: 0.7682
# Epoch 33/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.6028 - accuracy: 0.7613
# Epoch 34/100
# 18/18 [==============================] - 34s 2s/step - loss: 0.5378 - accuracy: 0.7786
# Epoch 35/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.5313 - accuracy: 0.7760
# Epoch 36/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.5530 - accuracy: 0.7856
# Epoch 37/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5163 - accuracy: 0.7865
# Epoch 38/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.5583 - accuracy: 0.7769
# Epoch 39/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5130 - accuracy: 0.7995
# Epoch 40/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5496 - accuracy: 0.7691
# Epoch 41/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4743 - accuracy: 0.8186
# Epoch 42/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.4187 - accuracy: 0.8281
# Epoch 43/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.4522 - accuracy: 0.8151
# Epoch 44/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4305 - accuracy: 0.8255
# Epoch 45/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.4512 - accuracy: 0.8194
# Epoch 46/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.3684 - accuracy: 0.8464
# Epoch 47/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.3732 - accuracy: 0.8429
# Epoch 48/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.3602 - accuracy: 0.8481
# Epoch 49/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.4194 - accuracy: 0.8281
# Epoch 50/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.3606 - accuracy: 0.8507
# Epoch 51/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.3711 - accuracy: 0.8455
# Epoch 52/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.4562 - accuracy: 0.8290
# Epoch 53/100
# 18/18 [==============================] - 45s 2s/step - loss: 0.3483 - accuracy: 0.8602
# Epoch 54/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.3933 - accuracy: 0.8394
# Epoch 55/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.3675 - accuracy: 0.8429
# Epoch 56/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.3003 - accuracy: 0.8681
# Epoch 57/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.3193 - accuracy: 0.8637
# Epoch 58/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.3136 - accuracy: 0.8655
# Epoch 59/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.2890 - accuracy: 0.8872
# Epoch 60/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3363 - accuracy: 0.8550
# Epoch 61/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2920 - accuracy: 0.8767
# Epoch 62/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.3937 - accuracy: 0.8403
# Epoch 63/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.3444 - accuracy: 0.8724
# Epoch 64/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.3109 - accuracy: 0.8628
# Epoch 65/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.2535 - accuracy: 0.8845
# Epoch 66/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.2493 - accuracy: 0.8898
# Epoch 67/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.2553 - accuracy: 0.8845
# Epoch 68/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.2220 - accuracy: 0.8941
# Epoch 69/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.2433 - accuracy: 0.8924
# Epoch 70/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2050 - accuracy: 0.9010
# Epoch 71/100
# 18/18 [==============================] - 45s 2s/step - loss: 0.2251 - accuracy: 0.9019
# Epoch 72/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.3116 - accuracy: 0.8698
# Epoch 73/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.2986 - accuracy: 0.8698
# Epoch 74/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.2887 - accuracy: 0.8733
# Epoch 75/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1988 - accuracy: 0.9028
# Epoch 76/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2039 - accuracy: 0.9045
# Epoch 77/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1731 - accuracy: 0.9141
# Epoch 78/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.2021 - accuracy: 0.9167
# Epoch 79/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.1897 - accuracy: 0.9167
# Epoch 80/100
# 18/18 [==============================] - 45s 3s/step - loss: 0.1953 - accuracy: 0.9201
# Epoch 81/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.2321 - accuracy: 0.9062
# Epoch 82/100
# 18/18 [==============================] - 48s 3s/step - loss: 0.1712 - accuracy: 0.9340
# Epoch 83/100
# 18/18 [==============================] - 45s 3s/step - loss: 0.1995 - accuracy: 0.9184
# Epoch 84/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2369 - accuracy: 0.9002
# Epoch 85/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.2139 - accuracy: 0.9219
# Epoch 86/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.2696 - accuracy: 0.8889
# Epoch 87/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.2150 - accuracy: 0.9175
# Epoch 88/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.1967 - accuracy: 0.9158
# Epoch 89/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.2016 - accuracy: 0.9253
# Epoch 90/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.1634 - accuracy: 0.9262
# Epoch 91/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1700 - accuracy: 0.9236
# Epoch 92/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1472 - accuracy: 0.9366
# Epoch 93/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1579 - accuracy: 0.9384
# Epoch 94/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.2341 - accuracy: 0.9089
# Epoch 95/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.1353 - accuracy: 0.9392
# Epoch 96/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1320 - accuracy: 0.9436
# Epoch 97/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.1438 - accuracy: 0.9375
# Epoch 98/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.1438 - accuracy: 0.9306
# Epoch 99/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.1556 - accuracy: 0.9436
# Epoch 100/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2785 - accuracy: 0.8924
# 36/36 [==============================] - 15s 311ms/step
# 10/10 [==============================] - 6s 288ms/step
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_18 (Conv1D)          (None, 40, 2048)          1333248
#
#  max_pooling1d_18 (MaxPooli  (None, 20, 2048)          0
#  ng1D)
#
#  batch_normalization_18 (Ba  (None, 20, 2048)          8192
#  tchNormalization)
#
#  conv1d_19 (Conv1D)          (None, 20, 1024)          10486784
#
#  max_pooling1d_19 (MaxPooli  (None, 10, 1024)          0
#  ng1D)
#
#  batch_normalization_19 (Ba  (None, 10, 1024)          4096
#  tchNormalization)
#
#  conv1d_20 (Conv1D)          (None, 10, 512)           2621952
#
#  max_pooling1d_20 (MaxPooli  (None, 5, 512)            0
#  ng1D)
#
#  batch_normalization_20 (Ba  (None, 5, 512)            2048
#  tchNormalization)
#
#  lstm_12 (LSTM)              (None, 5, 256)            787456
#
#  lstm_13 (LSTM)              (None, 128)               197120
#
#  dense_18 (Dense)            (None, 64)                8256
#
#  dropout_12 (Dropout)        (None, 64)                0
#
#  dense_19 (Dense)            (None, 32)                2080
#
#  dropout_13 (Dropout)        (None, 32)                0
#
#  dense_20 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 15451397 (58.94 MB)
# Trainable params: 15444229 (58.92 MB)
# Non-trainable params: 7168 (28.00 KB)
# _________________________________________________________________
# Epoch 1/100
# 18/18 [==============================] - 63s 2s/step - loss: 1.2511 - accuracy: 0.4332
# Epoch 2/100
# 18/18 [==============================] - 41s 2s/step - loss: 1.1166 - accuracy: 0.5330
# Epoch 3/100
# 18/18 [==============================] - 54s 3s/step - loss: 1.0261 - accuracy: 0.5825
# Epoch 4/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.9437 - accuracy: 0.6181
# Epoch 5/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.9540 - accuracy: 0.6345
# Epoch 6/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.9276 - accuracy: 0.6398
# Epoch 7/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.9110 - accuracy: 0.6788
# Epoch 8/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.8695 - accuracy: 0.6762
# Epoch 9/100
# 18/18 [==============================] - 37s 2s/step - loss: 0.8482 - accuracy: 0.6901
# Epoch 10/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.8711 - accuracy: 0.7188
# Epoch 11/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.8400 - accuracy: 0.7179
# Epoch 12/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.8203 - accuracy: 0.7109
# Epoch 13/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7782 - accuracy: 0.7318
# Epoch 14/100
# 18/18 [==============================] - 34s 2s/step - loss: 0.7813 - accuracy: 0.7283
# Epoch 15/100
# 18/18 [==============================] - 38s 2s/step - loss: 0.8343 - accuracy: 0.6936
# Epoch 16/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7587 - accuracy: 0.7361
# Epoch 17/100
# 18/18 [==============================] - 34s 2s/step - loss: 0.7109 - accuracy: 0.7552
# Epoch 18/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.7509 - accuracy: 0.7405
# Epoch 19/100
# 18/18 [==============================] - 34s 2s/step - loss: 0.7619 - accuracy: 0.7231
# Epoch 20/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7191 - accuracy: 0.7222
# Epoch 21/100
# 18/18 [==============================] - 33s 2s/step - loss: 0.7000 - accuracy: 0.7413
# Epoch 22/100
# 18/18 [==============================] - 36s 2s/step - loss: 0.7069 - accuracy: 0.7595
# Epoch 23/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.7013 - accuracy: 0.7630
# Epoch 24/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.6604 - accuracy: 0.7717
# Epoch 25/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.6544 - accuracy: 0.7873
# Epoch 26/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.6532 - accuracy: 0.7648
# Epoch 27/100
# 18/18 [==============================] - 62s 4s/step - loss: 0.6497 - accuracy: 0.7804
# Epoch 28/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.6324 - accuracy: 0.7839
# Epoch 29/100
# 18/18 [==============================] - 36s 2s/step - loss: 0.6172 - accuracy: 0.7839
# Epoch 30/100
# 18/18 [==============================] - 34s 2s/step - loss: 0.5885 - accuracy: 0.7847
# Epoch 31/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.5857 - accuracy: 0.7925
# Epoch 32/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.5956 - accuracy: 0.8056
# Epoch 33/100
# 18/18 [==============================] - 36s 2s/step - loss: 0.6069 - accuracy: 0.7899
# Epoch 34/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.5710 - accuracy: 0.8047
# Epoch 35/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.6124 - accuracy: 0.7960
# Epoch 36/100
# 18/18 [==============================] - 66s 4s/step - loss: 0.5572 - accuracy: 0.8056
# Epoch 37/100
# 18/18 [==============================] - 90s 5s/step - loss: 0.4986 - accuracy: 0.8090
# Epoch 38/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.5106 - accuracy: 0.8073
# Epoch 39/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.5657 - accuracy: 0.8003
# Epoch 40/100
# 18/18 [==============================] - 53s 3s/step - loss: 0.5307 - accuracy: 0.8047
# Epoch 41/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.5168 - accuracy: 0.8194
# Epoch 42/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.4811 - accuracy: 0.8168
# Epoch 43/100
# 18/18 [==============================] - 56s 3s/step - loss: 0.4420 - accuracy: 0.8368
# Epoch 44/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.4523 - accuracy: 0.8316
# Epoch 45/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.4332 - accuracy: 0.8316
# Epoch 46/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.3989 - accuracy: 0.8472
# Epoch 47/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.4254 - accuracy: 0.8394
# Epoch 48/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.4165 - accuracy: 0.8490
# Epoch 49/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3732 - accuracy: 0.8550
# Epoch 50/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3415 - accuracy: 0.8646
# Epoch 51/100
# 18/18 [==============================] - 51s 3s/step - loss: 0.3762 - accuracy: 0.8533
# Epoch 52/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.3496 - accuracy: 0.8602
# Epoch 53/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.2933 - accuracy: 0.8767
# Epoch 54/100
# 18/18 [==============================] - 60s 3s/step - loss: 0.3105 - accuracy: 0.8854
# Epoch 55/100
# 18/18 [==============================] - 58s 3s/step - loss: 0.3206 - accuracy: 0.8681
# Epoch 56/100
# 18/18 [==============================] - 58s 3s/step - loss: 0.3446 - accuracy: 0.8585
# Epoch 57/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.2872 - accuracy: 0.8802
# Epoch 58/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2486 - accuracy: 0.8976
# Epoch 59/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.2843 - accuracy: 0.8724
# Epoch 60/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.3394 - accuracy: 0.8750
# Epoch 61/100
# 18/18 [==============================] - 41s 2s/step - loss: 0.2976 - accuracy: 0.8924
# Epoch 62/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.2522 - accuracy: 0.8932
# Epoch 63/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.2408 - accuracy: 0.8898
# Epoch 64/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.2979 - accuracy: 0.8828
# Epoch 65/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.2977 - accuracy: 0.8950
# Epoch 66/100
# 18/18 [==============================] - 51s 3s/step - loss: 0.2950 - accuracy: 0.8811
# Epoch 67/100
# 18/18 [==============================] - 58s 3s/step - loss: 0.2214 - accuracy: 0.8967
# Epoch 68/100
# 18/18 [==============================] - 61s 3s/step - loss: 0.1762 - accuracy: 0.9314
# Epoch 69/100
# 18/18 [==============================] - 63s 4s/step - loss: 0.2049 - accuracy: 0.9175
# Epoch 70/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.2079 - accuracy: 0.9080
# Epoch 71/100
# 18/18 [==============================] - 51s 3s/step - loss: 0.1823 - accuracy: 0.9219
# Epoch 72/100
# 18/18 [==============================] - 48s 3s/step - loss: 0.2275 - accuracy: 0.9149
# Epoch 73/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.1894 - accuracy: 0.9340
# Epoch 74/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.1677 - accuracy: 0.9332
# Epoch 75/100
# 18/18 [==============================] - 46s 3s/step - loss: 0.1518 - accuracy: 0.9366
# Epoch 76/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.1890 - accuracy: 0.9392
# Epoch 77/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.2092 - accuracy: 0.9297
# Epoch 78/100
# 18/18 [==============================] - 61s 3s/step - loss: 0.1798 - accuracy: 0.9340
# Epoch 79/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.2334 - accuracy: 0.9193
# Epoch 80/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.1802 - accuracy: 0.9280
# Epoch 81/100
# 18/18 [==============================] - 50s 3s/step - loss: 0.1289 - accuracy: 0.9444
# Epoch 82/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.1527 - accuracy: 0.9401
# Epoch 83/100
# 18/18 [==============================] - 52s 3s/step - loss: 0.2166 - accuracy: 0.9366
# Epoch 84/100
# 18/18 [==============================] - 54s 3s/step - loss: 0.3106 - accuracy: 0.8915
# Epoch 85/100
# 18/18 [==============================] - 47s 3s/step - loss: 0.1785 - accuracy: 0.9366
# Epoch 86/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.1123 - accuracy: 0.9514
# Epoch 87/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1199 - accuracy: 0.9575
# Epoch 88/100
# 18/18 [==============================] - 53s 3s/step - loss: 0.1584 - accuracy: 0.9427
# Epoch 89/100
# 18/18 [==============================] - 42s 2s/step - loss: 0.1438 - accuracy: 0.9488
# Epoch 90/100
# 18/18 [==============================] - 43s 2s/step - loss: 0.1299 - accuracy: 0.9583
# Epoch 91/100
# 18/18 [==============================] - 55s 3s/step - loss: 0.3744 - accuracy: 0.8889
# Epoch 92/100
# 18/18 [==============================] - 60s 3s/step - loss: 0.3026 - accuracy: 0.8828
# Epoch 93/100
# 18/18 [==============================] - 57s 3s/step - loss: 0.1507 - accuracy: 0.9410
# Epoch 94/100
# 18/18 [==============================] - 44s 2s/step - loss: 0.1825 - accuracy: 0.9566
# Epoch 95/100
# 18/18 [==============================] - 49s 3s/step - loss: 0.1224 - accuracy: 0.9592
# Epoch 96/100
# 18/18 [==============================] - 45s 2s/step - loss: 0.1547 - accuracy: 0.9505
# Epoch 97/100
# 18/18 [==============================] - 63s 4s/step - loss: 0.0957 - accuracy: 0.9635
# Epoch 98/100
# 18/18 [==============================] - 56s 3s/step - loss: 0.0994 - accuracy: 0.9696
# Epoch 99/100
# ...
# Epoch 28/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5901 - accuracy: 0.7821
# Epoch 29/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5994 - accuracy: 0.7821
# Epoch 30/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5973 - accuracy: 0.7882
# Epoch 31/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5772 - accuracy: 0.7778
# Epoch 32/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4877 - accuracy: 0.8220
# Epoch 33/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5718 - accuracy: 0.7778
# Epoch 34/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.5431 - accuracy: 0.7743
# Epoch 35/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5333 - accuracy: 0.7882
# Epoch 36/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.6434 - accuracy: 0.7595
# Epoch 37/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5676 - accuracy: 0.7656
# Epoch 38/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4552 - accuracy: 0.8264
# Epoch 39/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5178 - accuracy: 0.8168
# Epoch 40/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.5558 - accuracy: 0.7917
# Epoch 41/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4781 - accuracy: 0.8212
# Epoch 42/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3891 - accuracy: 0.8550
# Epoch 43/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4227 - accuracy: 0.8464
# Epoch 44/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4270 - accuracy: 0.8377
# Epoch 45/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3655 - accuracy: 0.8507
# Epoch 46/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3607 - accuracy: 0.8568
# Epoch 47/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3624 - accuracy: 0.8481
# Epoch 48/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3280 - accuracy: 0.8733
# Epoch 49/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3715 - accuracy: 0.8481
# Epoch 50/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3165 - accuracy: 0.8689
# Epoch 51/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3254 - accuracy: 0.8707
# Epoch 52/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2885 - accuracy: 0.8793
# Epoch 53/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2880 - accuracy: 0.8715
# Epoch 54/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2916 - accuracy: 0.8785
# Epoch 55/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2885 - accuracy: 0.8698
# Epoch 56/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3225 - accuracy: 0.8715
# Epoch 57/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3735 - accuracy: 0.8429
# Epoch 58/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3556 - accuracy: 0.8542
# Epoch 59/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2775 - accuracy: 0.8759
# Epoch 60/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3376 - accuracy: 0.8611
# Epoch 61/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2948 - accuracy: 0.8724
# Epoch 62/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2620 - accuracy: 0.8767
# Epoch 63/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2592 - accuracy: 0.8819
# Epoch 64/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2246 - accuracy: 0.8837
# Epoch 65/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2743 - accuracy: 0.8802
# Epoch 66/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.3505 - accuracy: 0.8724
# Epoch 67/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.2421 - accuracy: 0.8932
# Epoch 68/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2357 - accuracy: 0.8863
# Epoch 69/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.4157 - accuracy: 0.8299
# Epoch 70/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2738 - accuracy: 0.8767
# Epoch 71/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2694 - accuracy: 0.8863
# Epoch 72/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2343 - accuracy: 0.8880
# Epoch 73/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2059 - accuracy: 0.8906
# Epoch 74/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2375 - accuracy: 0.8967
# Epoch 75/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2918 - accuracy: 0.8898
# Epoch 76/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2092 - accuracy: 0.8967
# Epoch 77/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1831 - accuracy: 0.9184
# Epoch 78/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2223 - accuracy: 0.9036
# Epoch 79/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2694 - accuracy: 0.8993
# Epoch 80/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1908 - accuracy: 0.9115
# Epoch 81/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1761 - accuracy: 0.9141
# Epoch 82/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1960 - accuracy: 0.9149
# Epoch 83/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2336 - accuracy: 0.9045
# Epoch 84/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1646 - accuracy: 0.9349
# Epoch 85/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2179 - accuracy: 0.9123
# Epoch 86/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2236 - accuracy: 0.9089
# Epoch 87/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1713 - accuracy: 0.9280
# Epoch 88/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1610 - accuracy: 0.9392
# Epoch 89/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1670 - accuracy: 0.9384
# Epoch 90/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1703 - accuracy: 0.9410
# Epoch 91/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.2114 - accuracy: 0.9158
# Epoch 92/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2076 - accuracy: 0.9306
# Epoch 93/100
# 18/18 [==============================] - 40s 2s/step - loss: 0.1632 - accuracy: 0.9418
# Epoch 94/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1279 - accuracy: 0.9505
# Epoch 95/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1940 - accuracy: 0.9227
# Epoch 96/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2404 - accuracy: 0.8993
# Epoch 97/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1839 - accuracy: 0.9245
# Epoch 98/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.2297 - accuracy: 0.9054
# Epoch 99/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1384 - accuracy: 0.9418
# Epoch 100/100
# 18/18 [==============================] - 39s 2s/step - loss: 0.1148 - accuracy: 0.9549
# 36/36 [==============================] - 14s 317ms/step
# 10/10 [==============================] - 5s 283ms/step
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Average Train Accuracy: 0.7848090277777777
# Average Train AUC Score: 0.9174008808574392
# Average Train MCC Score: 0.6611743333408496
#
#
# Average Train Classification Report:
#               precision    recall  f1-score   support
#
#     artifact    0.95522   1.00000   0.97710       128
#     extrahls    0.68085   0.78049   0.72727        41
#   extrastole    0.00000   0.00000   0.00000        70
#       murmur    0.75556   0.11409   0.19825       298
#       normal    0.63931   0.96260   0.76833       615
#
#     accuracy                        0.68229      1152
#    macro avg    0.60619   0.57144   0.53419      1152
# weighted avg    0.66711   0.68229   0.59591      1152
#
# Average Test Accuracy: 0.6923875432525952
# Average Test AUC Score: 0.8181325816138647
# Average Test MCC Score: 0.5003284958323775
#
#
# Average Test Classification Report:
#               precision    recall  f1-score   support
#
#     artifact    0.94118   1.00000   0.96970        32
#     extrahls    0.50000   0.70000   0.58333        10
#   extrastole    0.00000   0.00000   0.00000        18
#       murmur    1.00000   0.08000   0.14815        75
#       normal    0.62128   0.94805   0.75064       154
#
#     accuracy                        0.66090       289
#    macro avg    0.61249   0.54561   0.49036       289
# weighted avg    0.71209   0.66090   0.56600       289
